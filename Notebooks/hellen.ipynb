# %% [markdown]
# ## Reading and understanding the dataset

# %%
import pandas as pd
import sqlite3
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn = sqlite3.connect("../im.db/im.db")

# %%
tables= pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print(tables)
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
movie_basics =pd.read_sql_query("""
    SELECT * FROM movie_basics
""", conn)

movie_basics.head(10)
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
# 6  tt0112502                          Bigfoot                     Bigfoot
# 7  tt0137204                  Joe Finds Grace             Joe Finds Grace
# 8  tt0139613                       O Silêncio                  O Silêncio
# 9  tt0144449            Nema aviona za Zagreb       Nema aviona za Zagreb
#
#    start_year  runtime_minutes                      genres
# 0        2013            175.0          Action,Crime,Drama
# ...

# %%
movie_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
# Null values spotted are in the columns original title, runtime minutes and genres

# %%
movie_basics.dropna()
# Out:
#          movie_id                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# ...           ...                                                ...
# 146134  tt9916160                                         Drømmeland
# 146135  tt9916170                                      The Rehearsal
# 146136  tt9916186  Illenau - die Geschichte einer ehemaligen Heil...
# 146137  tt9916190                                          Safeguard
# 146139  tt9916538                                Kuambil Lagi Hatiku
#
#                                            original_title  start_year  \
# ...

# %%
movie_basics.duplicated().sum()
# Out:
# 0

# %%
movie_basics.isna().sum()
# Out:
# movie_id               0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
movie_basics.drop('runtime_minutes', axis=1, inplace=True)

# %%
movie_basics['genres'] = movie_basics['genres'].fillna('unknown')
movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
movie_basics['original_title'] = movie_basics['original_title'].fillna('unknown')
movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
movie_basics.isna().sum()
# Out:
# movie_id          0
# primary_title     0
# original_title    0
# start_year        0
# genres            0
# dtype: int64

# %%
movie_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   movie_id        146144 non-null  object
#  1   primary_title   146144 non-null  object
#  2   original_title  146144 non-null  object
#  3   start_year      146144 non-null  int64
#  4   genres          146144 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 5.6+ MB

# %%
movie_ratings =pd.read_sql_query("""
    SELECT * FROM movie_ratings
""", conn)
movie_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
movie_ratings = movie_ratings.rename(columns={
    'averagerating': 'average_rating',
    'numvotes':'num_votes'
})

# %%
movie_ratings.isna().sum()
# Out:
# movie_id          0
# average_rating    0
# num_votes         0
# dtype: int64

# %%
movie_ratings =pd.read_sql_query("""
    SELECT * FROM movie_ratings
""", conn)
movie_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
movie_basics.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year                genres
# 0        2013    Action,Crime,Drama
# 1        2019       Biography,Drama
# 2        2018                 Drama
# 3        2018          Comedy,Drama
# 4        2017  Comedy,Drama,Fantasy

# %%
movie_ratings.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %% [markdown]
# ## Reading the pandas dataset

# %%
df_bom = pd.read_csv("./bom.movie_gross.csv")
df_bom
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df_tm= pd.read_csv("./tmdb.movies.csv")
df_tm
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
df_tn= pd.read_csv("./tn.movie_budgets.csv")
df_tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %% [markdown]
# ## Merging data sets and SQL

# %%
# loading the clean data sets
df_bom_cleaned = pd.read_csv("cleaned-bom.movies.csv")
df_bom_cleaned
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
df_tm_cleaned = pd.read_csv("tmdb.movies.csv")
df_tm_cleaned
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
df_tn_cleaned = pd.read_csv("cleaned-tn.movies_budgets.csv")
df_tn_cleaned
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       avatar
# 1      2  May 20, 2011  pirates of the caribbean: on stranger tides
# 2      3   Jun 7, 2019                                 dark phoenix
# 3      4   May 1, 2015                      avengers: age of ultron
# 4      5  Dec 15, 2017            star wars ep. viii: the last jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       red 11
# 5778  79   Apr 2, 1999                                    following
# 5779  80  Jul 13, 2005                return to the land of wonders
# 5780  81  Sep 29, 2015                         a plague so pleasant
# 5781  82   Aug 5, 2005                            my date with drew
#
#       production_budget  domestic_gross  worldwide_gross        profit
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# ...

# %% [markdown]
# ## Merging the two tables in the IMDB database to create a IMDB dataframe

# %%
imdb_df = movie_basics.merge(movie_ratings, on="movie_id", how="left")
imdb_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#checking the column names in both data frames
print(imdb_df.columns)
print(df_bom_cleaned.columns)
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year', 'genres',
#        'averagerating', 'numvotes'],
#       dtype='object')
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
# the first merger between IMDB and Box office movies 
merged_df= imdb_df.merge(
    df_bom_cleaned,
    left_on=['primary_title', 'start_year'],
    right_on=['title', 'year'],
    how='inner'
)
merged_df
# Out:
#        movie_id                    primary_title  \
# 0     tt0315642                            Wazir
# 1     tt0337692                      On the Road
# 2     tt0359950  The Secret Life of Walter Mitty
# 3     tt0365907      A Walk Among the Tombstones
# 4     tt0369610                   Jurassic World
# ...         ...                              ...
# 1868  tt8362680                         Mountain
# 1869  tt8404272           How Long Will I Love U
# 1870  tt8427036                  Helicopter Eela
# 1871  tt9078374                      Last Letter
# 1872  tt9151704        Burn the Stage: The Movie
#
#                        original_title  start_year                   genres  \
# 0                               Wazir        2016       Action,Crime,Drama
# 1                         On the Road        2012  Adventure,Drama,Romance
# 2     The Secret Life of Walter Mitty        2013   Adventure,Comedy,Drama
# ...

# %% [markdown]
# ## Merging the rest of the pandas dataframes with the primary dataframe ie IMDB dataframe
# In this step we are supposed to merge the main dataframe to the other dataframes i.e box office movies, The movie database and the Numbers to come up with one comprehensive dataset to help clearly analyze the patterns in the movie industry.

# %%
# checking the columns on both data frames
print(df_tm_cleaned.columns)
print(merged_df.columns)
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')
# Index(['movie_id', 'primary_title', 'original_title', 'start_year', 'genres',
#        'averagerating', 'numvotes', 'title', 'studio', 'domestic_gross',
#        'foreign_gross', 'year'],
#       dtype='object')

# %%
#checking the data types
print(merged_df[['primary_title', 'start_year']].dtypes)
print(df_tm_cleaned[['title', 'release_date']].dtypes)
# Out:
# primary_title    object
# start_year        int64
# dtype: object
# title           object
# release_date    object
# dtype: object

# %%
#changing the data type of start year from an integer to string
merged_df['start_year'] = merged_df['start_year'].astype(str)

# %%
# Changing release year to release date for merging purposes
df_tm_cleaned['release_year'] = pd.to_datetime(df_tm_cleaned['release_date'], errors='coerce').dt.year

# %%
#checking the length of both databases
print(len(merged_df))
print(len(df_tm_cleaned))
# Out:
# 1873
# 26517

# %%
#changing the case to lower case 
merged_df['primary_title'] = merged_df['primary_title'].str.strip().str.lower()
df_tm_cleaned['title'] = df_tm_cleaned['title'].str.strip().str.lower()

# %%
df_tm_cleaned['release_date'] = df_tm_cleaned['release_date'].astype(str).str.extract(r'(\d{4})')[0]
merged_df['start_year'] = merged_df['start_year'].astype(str).str.extract(r'(\d{4})')[0]

# %%
merged_final = merged_df.merge(
    df_tm_cleaned,
    left_on=['primary_title', 'start_year'],
    right_on=['title', 'release_date'],
    how='inner'
)
merged_final
# Out:
#        movie_id                    primary_title  \
# 0     tt0315642                            wazir
# 1     tt0337692                      on the road
# 2     tt0359950  the secret life of walter mitty
# 3     tt0365907      a walk among the tombstones
# 4     tt0369610                   jurassic world
# ...         ...                              ...
# 1759  tt8097306                    nobody's fool
# 1760  tt8267604                        capernaum
# 1761  tt8290698               the spy gone north
# 1762  tt8404272           how long will i love u
# 1763  tt9078374                      last letter
#
#                      original_title_x start_year                   genres  \
# 0                               Wazir       2016       Action,Crime,Drama
# 1                         On the Road       2012  Adventure,Drama,Romance
# 2     The Secret Life of Walter Mitty       2013   Adventure,Comedy,Drama
# 3         A Walk Among the Tombstones       2014       Action,Crime,Drama
# ...

# %%
print(merged_final.shape)
# Out:
# (1764, 23)

# %%
merged_final.isna().sum()
# Out:
# movie_id              0
# primary_title         0
# original_title_x      0
# start_year            0
# genres                0
# averagerating        22
# numvotes             22
# title_x               0
# studio                0
# domestic_gross        0
# foreign_gross         0
# year                  0
# Unnamed: 0            0
# genre_ids             0
# id                    0
# original_language     0
# original_title_y      0
# popularity            0
# release_date          0
# title_y               0
# vote_average          0
# vote_count            0
# release_year          0
# dtype: int64

# %%
print(df_tn_cleaned.columns)
print(merged_final.columns)
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'profit'],
#       dtype='object')
# Index(['movie_id', 'primary_title', 'original_title_x', 'start_year', 'genres',
#        'averagerating', 'numvotes', 'title_x', 'studio', 'domestic_gross',
#        'foreign_gross', 'year', 'Unnamed: 0', 'genre_ids', 'id',
#        'original_language', 'original_title_y', 'popularity', 'release_date',
#        'title_y', 'vote_average', 'vote_count', 'release_year'],
#       dtype='object')

# %%
print(merged_final[['movie_id', 'start_year']].dtypes)
print(df_tn_cleaned[['id', 'release_date']].dtypes)
# Out:
# movie_id      object
# start_year    object
# dtype: object
# id               int64
# release_date    object
# dtype: object

# %%
df_tn_cleaned['id'] = df_tn_cleaned['id'].astype(str)

# %%
merged_final['start_year'] = merged_final['start_year'].astype(str)
df_tm_cleaned['release_date'] = df_tm_cleaned['release_date'].astype(str)
df_tm_cleaned['id'] = df_tm_cleaned['id'].astype(str)
df_tm_cleaned['release_date'] = df_tm_cleaned['release_date'].astype(str)

# %%
merged_final['movie_id'] = merged_final['movie_id'].str.strip()
merged_final['start_year'] = merged_final['start_year'].str.strip()
df_tm_cleaned['id'] = df_tm_cleaned['id'].str.strip()
df_tm_cleaned['release_date'] = df_tm_cleaned['release_date'].str.strip()

# %%
print(merged_final[['movie_id', 'start_year']].dtypes)
print(df_tn_cleaned[['id', 'release_date']].dtypes)
# Out:
# movie_id      object
# start_year    object
# dtype: object
# id              object
# release_date    object
# dtype: object

# %%
print(merged_final[['movie_id', 'start_year']].head(10))
print(df_tm_cleaned[['id', 'release_date']].head(10))
# Out:
#     movie_id start_year
# 0  tt0315642       2016
# 1  tt0337692       2012
# 2  tt0359950       2013
# 3  tt0365907       2014
# 4  tt0369610       2015
# 5  tt0376136       2011
# 6  tt0376479       2016
# 7  tt0376479       2016
# 8  tt0383010       2012
# 9  tt0398286       2010
#       id release_date
# 0  12444         2010
# 1  10191         2010
# 2  10138         2010
# 3    862         1995
# 4  27205         2010
# 5  32657         2010
# 6  19995         2009
# 7  10193         2010
# 8  20352         2010
# 9  38055         2010

# %%
merged_final['primary_title'] = merged_final['primary_title'].str.lower().str.strip()
df_tm_cleaned['title'] = df_tm_cleaned['title'].str.lower().str.strip()

# %%
df_tm_cleaned['release_year'] = pd.to_datetime(df_tm_cleaned['release_date'], errors='coerce').dt.year.astype(str)
merged_final['start_year'] = merged_final['start_year'].astype(str)

# %%
merged_final_table = merged_final.merge(
    df_tm_cleaned,
    left_on=['primary_title', 'start_year'],
    right_on=['title', 'release_year'],
    how='inner'
)
merged_final_table
# Out:
#        movie_id                    primary_title  \
# 0     tt0315642                            wazir
# 1     tt0337692                      on the road
# 2     tt0359950  the secret life of walter mitty
# 3     tt0365907      a walk among the tombstones
# 4     tt0369610                   jurassic world
# ...         ...                              ...
# 2049  tt8097306                    nobody's fool
# 2050  tt8267604                        capernaum
# 2051  tt8290698               the spy gone north
# 2052  tt8404272           how long will i love u
# 2053  tt9078374                      last letter
#
#                      original_title_x start_year                   genres  \
# 0                               Wazir       2016       Action,Crime,Drama
# 1                         On the Road       2012  Adventure,Drama,Romance
# 2     The Secret Life of Walter Mitty       2013   Adventure,Comedy,Drama
# 3         A Walk Among the Tombstones       2014       Action,Crime,Drama
# ...

# %%
merged_final_table.isna().sum()
# Out:
# movie_id                0
# primary_title           0
# original_title_x        0
# start_year              0
# genres                  0
# averagerating          38
# numvotes               38
# title_x                 0
# studio                  0
# domestic_gross          0
# foreign_gross           0
# year                    0
# Unnamed: 0_x            0
# genre_ids_x             0
# id_x                    0
# original_language_x     0
# original_title_y        0
# popularity_x            0
# release_date_x          0
# title_y                 0
# vote_average_x          0
# vote_count_x            0
# release_year_x          0
# Unnamed: 0_y            0
# genre_ids_y             0
# id_y                    0
# original_language_y     0
# original_title          0
# popularity_y            0
# release_date_y          0
# title                   0
# vote_average_y          0
# vote_count_y            0
# release_year_y          0
# dtype: int64

# %%
print(merged_final_table.columns)
# Out:
# Index(['movie_id', 'primary_title', 'original_title_x', 'start_year', 'genres',
#        'averagerating', 'numvotes', 'title_x', 'studio', 'domestic_gross',
#        'foreign_gross', 'year', 'Unnamed: 0_x', 'genre_ids_x', 'id_x',
#        'original_language_x', 'original_title_y', 'popularity_x',
#        'release_date_x', 'title_y', 'vote_average_x', 'vote_count_x',
#        'release_year_x', 'Unnamed: 0_y', 'genre_ids_y', 'id_y',
#        'original_language_y', 'original_title', 'popularity_y',
#        'release_date_y', 'title', 'vote_average_y', 'vote_count_y',
#        'release_year_y'],
#       dtype='object')

# %%
merged_final_table = merged_final_table.drop(
    ['title_x', 'original_title_y', 'title_y', 'id_x', 'release_date_x', 'Unnamed: 0_y', 'genre_ids_x',], 
    axis=1, 
)

# %%
merged_final_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2054 entries, 0 to 2053
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   movie_id             2054 non-null   object
#  1   primary_title        2054 non-null   object
#  2   original_title_x     2054 non-null   object
#  3   start_year           2054 non-null   object
#  4   genres               2054 non-null   object
#  5   averagerating        2016 non-null   float64
#  6   numvotes             2016 non-null   float64
#  7   studio               2054 non-null   object
#  8   domestic_gross       2054 non-null   float64
#  9   foreign_gross        2054 non-null   float64
#  10  year                 2054 non-null   int64
#  11  Unnamed: 0_x         2054 non-null   int64
#  12  original_language_x  2054 non-null   object
#  13  popularity_x         2054 non-null   float64
#  14  vote_average_x       2054 non-null   float64
# ...

# %%
merged_final_table = merged_final_table.drop(
    ['year', 'Unnamed: 0_x', 'original_language_x', 'release_year_x', 'genre_ids_y', 'id_y', 'vote_count_y', 'release_year_y'],
    axis=1
)

# %%
merged_final_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2054 entries, 0 to 2053
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   movie_id             2054 non-null   object
#  1   primary_title        2054 non-null   object
#  2   original_title_x     2054 non-null   object
#  3   start_year           2054 non-null   object
#  4   genres               2054 non-null   object
#  5   averagerating        2016 non-null   float64
#  6   numvotes             2016 non-null   float64
#  7   studio               2054 non-null   object
#  8   domestic_gross       2054 non-null   float64
#  9   foreign_gross        2054 non-null   float64
#  10  popularity_x         2054 non-null   float64
#  11  vote_average_x       2054 non-null   float64
#  12  vote_count_x         2054 non-null   int64
#  13  original_language_y  2054 non-null   object
#  14  original_title       2054 non-null   object
# ...
